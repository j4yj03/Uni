# %%
import pandas as pd
import numpy as np
from scipy.io import loadmat
from sys import getsizeof

import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.gridspec as gridspec
import matplotlib.image as mpimg

from sklearn.mixture import GaussianMixture

from sklearn.manifold import TSNE

# %load_ext autoreload
# %autoreload 2

# %%
from scipy import interpolate

def crop_and_resample_2darray(arr, x_crop, y_crop, resample, *args, **kwargs):
    """Crop a 2darray and resize the data"""
    
    len_x_crop = x_crop[1]-x_crop[0]
    len_y_crop = y_crop[1]-y_crop[0]

    arr_crop = arr[x_crop[0]:x_crop[1], y_crop[0]:y_crop[1]]
    f = interpolate.interp2d(np.arange(len_y_crop), 
                             np.arange(len_x_crop), 
                             arr_crop, 
                             *args, **kwargs)
    result = f(np.arange(len_x_crop, step=len_x_crop/resample[1]), 
             np.arange(len_y_crop, step=len_y_crop/resample[0]))
    return result

# %%
path = "D:/Documents/Uni/Special Engineering/Projektdaten/"

files = ["fftArray_defectLines.mat",
         "fftArray_goodLines.mat",
         "realSpace_defectLines.mat",
         "realSpace_goodLines.mat",
         "timeTable_defectLines.mat",
         "timeTable_goodLines.mat"]

keys =['fftFeat','fftFeat','realSpace','realSpace','timeTable','timeTable']


mat = []
data =[]

for f in files:
    mat.append(loadmat(path+f))

    
for i, m in enumerate(mat[:-2]):
    print(getsizeof(m[keys[i]]),np.shape(m[keys[i]]),np.max(m[keys[i]]))
    data.append(pd.DataFrame(m[keys[i]]))
    
#data = mat['fftFeat']
# Out:
# 112 (111, 17089) 26.413447263145173
# 112 (109, 17236) 16.648241834407273
# 112 (223, 17089) 590.1683374744971
# 112 (218, 17236) 592.5773385229529

# %%
for i, m in enumerate(mat[-1:]):
    vec = m['__function_workspace__'][0]
    print(len(vec))#-17280000)
    data.append(pd.DataFrame(vec))
    for _ in m['None']:
        for val in _:
            for k in val:
                print(_,val,k)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=100)
pca2 = PCA(n_components=100)

# %%
ds = pca.fit_transform(data[0].T)
#ds = ds.T

#ds = pca2.fit_transform(ds)

# %%
print(np.shape(data[0]))
#print(pca.singular_values_)
#print(pca.explained_variance_ratio_)
print(np.shape(ds.T))

# %%
#print(type(data[:-3]),np.shape(data[:-3]))

fft = []

fft.append(data[0][2:102].T[0:17000])
fft.append(data[1][0:100].T[0:17000])


#slice = [arr[i][0:2] for i in range(0,2)]

#print(data[:-3],'\n',fft)

#for i,d in enumerate(data[:-3]):
#    print(i, np.shape(d),'\n',np.shape(fft[i]))
    

#print(type(fft),np.shape(fft))

X_train = []

ra = range(0,17000) #65:95

for ind, ds in enumerate(fft):
    
    #print(ds.head())
    
    ds = ds.T[ra]
    ds = ds.reset_index(drop=True)
    
    print(np.shape(ds), np.size(ds))
    ds = ds / np.max(ds) # 0...1

    X_train.append(pd.DataFrame(ds.T))
    
    fig = plt.figure(figsize=(14,12))
    ax = fig.add_subplot(111)
    ax.set_title(files[ind])
    mat = ax.matshow(ds, cmap = cm.magma)
    
    fig.colorbar(mat, ax=ax, orientation='vertical')
    ax.set_aspect('auto')
    
    
    
diff = X_train[0].T - X_train[1].T

#diff = diff / np.max(diff)

#diff = diff[0][~np.isnan(diff[0])]
#mask = ~np.isnan(diff[0])

#difference = diff[0]

#print(diff)


print(np.shape(diff), np.size(diff))

fig = plt.figure(figsize=(14,12))
ax = fig.add_subplot(111)
ax.set_title('diff')
mat = ax.matshow(diff, cmap = cm.BrBG) #cividis
fig.colorbar(mat, ax=ax, orientation='vertical')
ax.set_aspect('auto')
# Out:
# (100, 17000) 1700000
# (100, 17000) 1700000
# (100, 17000) 1700000

# %%
# braun = goodlines
# türkis = defectlines

# %%
X_train.append(diff.T)

# %%
diff = np.ma.array(difference, mask = mask)

# %%
np.shape(diff)

# %%
#https://matplotlib.org/3.1.1/gallery/images_contours_and_fields/interpolation_methods.html

print(X_train)

print(np.shape(X_train))


for i, col in enumerate(X_train):
    pass
    #print(fft[0][i])
    
#print(fft[0][0])

# %%
#models = []
min_cluster = 1
max_cluster = 10

h, w = len(X_train), max_cluster;
bic = [[0 for x in range(w)] for y in range(h)] 


for ind, ds in enumerate(X_train):
    for i in range(min_cluster, max_cluster):
        print('GM on ds',ind,'with shape',np.shape(ds),'with',i,'components')
        gm = GaussianMixture(n_components=i, n_init=3, verbose=2)
        gm.fit(ds)

        bic[ind][i] = gm.bic(ds)
        #models.append(gm)
# Out:
# GM on ds 0 with shape (17000, 100) with 1 components
# Initialization 0
# Initialization converged: True	 time lapse 0.30220s	 ll 173.27064
# Initialization 1
# Initialization converged: True	 time lapse 0.28623s	 ll 173.27064
# Initialization 2
# Initialization converged: True	 time lapse 0.27028s	 ll 173.27064
# GM on ds 0 with shape (17000, 100) with 2 components
# Initialization 0
#   Iteration 10	 time lapse 1.30750s	 ll change 0.01016
# Initialization converged: True	 time lapse 2.01561s	 ll 179.17861
# Initialization 1
#   Iteration 10	 time lapse 1.12499s	 ll change 0.01017
# Initialization converged: True	 time lapse 1.70145s	 ll 179.17861
# Initialization 2
#   Iteration 10	 time lapse 1.12000s	 ll change 0.01016
# Initialization converged: True	 time lapse 1.73436s	 ll 179.17862
# GM on ds 0 with shape (17000, 100) with 3 components
# Initialization 0
#   Iteration 10	 time lapse 1.85504s	 ll change 0.01881
#   Iteration 20	 time lapse 1.68051s	 ll change 0.00328
# ...

# %%
n_best =[]

for b in bic:
    fig = plt.figure(figsize=(10,8))
    
    plt.plot(b)
    plt.scatter(range(1, max_cluster)[np.argmin(b)], np.min(b), color='r')
    plt.show()
    print('min',np.min(b),'at',range(1, max_cluster)[np.argmin(b)])
    n_best.append(np.min(b))
# Out:
# min -6047266.702717147 at 5
# min -6069625.896674202 at 6
# min -4673250.617179327 at 3

# %%
models = []

gm = []

gm_defect = GaussianMixture(n_components=5, n_init=3, verbose=2)
gm.append(gm_defect)
gm_good = GaussianMixture(n_components=5, n_init=3, verbose=2)
gm.append(gm_good)
gm_diff = GaussianMixture(n_components=3, n_init=3, verbose=2)
gm.append(gm_diff)

for ds, mod in zip(X_train, gm):

    mod.fit(ds)

    print(mod.converged_)
    print(mod.n_iter_)
    models.append(mod)
# Out:
# Initialization 0
#   Iteration 10	 time lapse 3.04984s	 ll change 0.07871
#   Iteration 20	 time lapse 2.87731s	 ll change 0.01474
#   Iteration 30	 time lapse 2.94114s	 ll change 0.00502
#   Iteration 40	 time lapse 2.79652s	 ll change 0.00345
#   Iteration 50	 time lapse 2.74466s	 ll change 0.00251
# Initialization converged: True	 time lapse 16.01219s	 ll 184.83784
# Initialization 1
#   Iteration 10	 time lapse 3.10969s	 ll change 0.13102
#   Iteration 20	 time lapse 2.64393s	 ll change 0.01035
#   Iteration 30	 time lapse 2.63196s	 ll change 0.00114
# Initialization converged: True	 time lapse 8.66483s	 ll 184.90892
# Initialization 2
#   Iteration 10	 time lapse 3.24931s	 ll change 0.13967
#   Iteration 20	 time lapse 2.60503s	 ll change 0.00866
#   Iteration 30	 time lapse 2.50929s	 ll change 0.00230
# Initialization converged: True	 time lapse 9.63424s	 ll 184.90847
# True
# 31
# Initialization 0
#   Iteration 10	 time lapse 3.22538s	 ll change 0.09519
# ...

# %%
labels = []

for ind, m in enumerate(models):

    labels.append(m.predict(X_train[ind]))

# %%
len(l)

# %%
title = ['bad lines', 'good lines', 'difference']

i = 10

tsne = TSNE(n_components=2,  perplexity=i)

for  l, t, X in zip(labels, title, X_train):

    
    Y = tsne.fit_transform(X)
    
    fig = plt.figure(figsize=(12,12))
    ax = fig.add_subplot(111)
    ax.set_title(t)
    plt.scatter(X[80], X[79], marker='.', c=l)
    plt.show()
     
    fig = plt.figure(figsize=(12,12))
    ax = fig.add_subplot(111)
    ax.set_title(f'{t}: tsne reduced p={i}')
    plt.scatter(Y[:,0], Y[:,1], marker='.', c=l)
    plt.show()
    #ax.matshow(X, c=labels)

#ax.set_aspect('auto')

# %%
# Out:
# [  1   2   3   4   5   6   8  11  14  18  23  29  37  48  61  78 100]

# %%
title = ['bad lines', 'good lines', 'difference']

lr = 50
a = np.logspace(0.3,2,17)
p = a.astype(int)


for  l, t, X in zip(labels, title, X_train):
    for i in p:
        print(f't-sne p={i} learning_rate={lr} for {t} {np.shape(X)}')
        tsne = TSNE(n_components=2,  perplexity=i, learning_rate=lr)
        Y = tsne.fit_transform(X)

        fig = plt.figure(figsize=(12,12))
        ax = fig.add_subplot(111)
        ax.set_title(f'{t}: tsne reduced p={i}')
        plt.scatter(Y[:,0], Y[:,1], marker='.', c=l)
        plt.show()
    #ax.matshow(X, c=labels)

#ax.set_aspect('auto')
# Out:
# t-sne p=1 learning_rate=50 for bad lines ((17000, 100))

# %%
# display predicted scores by the model as a contour plot
x = np.linspace(-20., 30.)
y = np.linspace(-20., 40.)

X, Y = np.meshgrid(x, y)
XX = np.array([X.ravel(), Y.ravel()]).T

Z = -gm.score_samples(XX)
Z = Z.reshape(X.shape)

CS = plt.contour(X, Y, Z, norm=LogNorm(vmin=1.0, vmax=1000.0),
                 levels=np.logspace(0, 3, 10))
CB = plt.colorbar(CS, shrink=0.8, extend='both')
plt.scatter(fft[0][:, 0], fft[0][:, 1], .8) #X[80], X[79]

plt.title('Negative log-likelihood predicted by a GMM')
plt.axis('tight')
plt.show()
