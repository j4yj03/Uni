# %% [markdown]
# Dieses Jupyter Notebook präsentiert die Ergenisse des ersten Projektes des Moduls M30: Special Engineering. Thema des ersten Projektes ist die lineare Regression. Als Datenset wird das von sklearn bereitgestellte "Boston Housing Dataset" verwendet.

# %%
###############################################################################
# Boston Dataset: lineare Regression
# Sidney Göhler 544131
#### IKT (M)
# Special Engineering SoSe20
# Prof. Dr. Andreas Zeiser
###############################################################################
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.gridspec as gridspec
# import seaborn as sns #pip install searborn
import lineare_regression as lr
from sklearn.datasets import load_boston
from itertools import chain, combinations_with_replacement, product

# %%
#############################################
# Hilfsfunktionen
#############################################


def printhead(prefix="", array=None, lab=None):
    df = pd.DataFrame(array, columns=lab)
    print(prefix)
    print(train.head())
    print("shape: ", train.shape)
    print()


def columnNames(listToExtend, degree):
    list = []
    label = ""
    combinations = chain.from_iterable(
        combinations_with_replacement(listToExtend, i)
        for i in range(1, degree + 1))

    for combi in combinations:
        # print(combi)
        for c in combi:
            label = label + str(c)

        list.append(label)
        label = ""

    return list

def plotlearningcurve(over,text):
    
    fig = plt.figure(figsize=(14, 16))
    gs = gridspec.GridSpec(2, 1)
    ax = plt.subplot(gs[0])
    ax2 = plt.subplot(gs[1])
    ax.set_title(f'RMSE bei verschiedenen {text}')
    ax.plot(over, np.sqrt(mse_test), label='testdata')
    ax.plot(over, np.sqrt(mse_train), label='trainingdata')
    ax.set_ylabel('root mse')
    ax.set_xlabel(f'{text}')
    ax.set_ylim(0,max(np.sqrt(mse_test))+1)
    ax.set_xlim(0,max(over)+1)
    ax.legend()
    ax2.set_title(f'RMSE bei verschiedenen {text} (vergroessert)')
    ax2.plot(over, np.sqrt(mse_test), label='testdata')
    ax2.plot(over, np.sqrt(mse_train), label='trainingdata')
    ax2.set_ylabel('root mse')
    ax2.set_xlabel(f'{text}')
    # ax2.set_xlim(110,160)
    # ax2.set_ylim(2.75,3.7)
    ax2.set_xlim(250,400)
    ax2.set_ylim(1,3)
    ax2.legend()
    plt.savefig(f'learncurve_{text}.png')
    plt.show()
        

def linear(degree=[1], alpha=[0], size=[100]):

    if not all(type(i) in (list, tuple, set) for i in [degree, alpha, size]):
        # if not type(degree) in (list, tuple, set, frozenset):
        print('WARNING: Hyperparameter muessen als Liste uebergeben werden.\n'
              + 'Verwende d=1 a=0 s=100.\n\n\n')
        degree = [1]
        alpha = [0]
        size = [100]

    r2_score_ridge = []
    mse_test = []
    mse_train = []
    cost = []
    theta_ridge = []
    fx = []
    legend = []
    #12345
    hyperparameter = list(product(degree, alpha, size))
    #hyperparameter =[[1,0.01,405],[2,0.01,405]]# [[1,600,200],[2,45339,405]]#,[3,8000000,200]]


    fig = plt.figure(figsize=(20, 8))
    gs = gridspec.GridSpec(1, 2)
    ax = plt.subplot(gs[0])

    ax2 = plt.subplot(gs[1])


    for hypr in hyperparameter:
        d, a, s = hypr  # Polynomengrad, alpha und datensetgroesse

        X_tr = X_train[:s]
        y_tr = y_train[:s]
        X_te = X_test#[:s]
        y_te = y_test#[:s]

        print(f'###############\ncalculating and plotting for:\n'
              + f'polynomialdegree = {d}\nalpha = {a}\n'
              + f'datasetsize = {np.shape(X_tr)}...\n')

        X_tr_n = lr.QuadraticFeatures_fit_transform(X_tr, d)
        X_te_n = lr.QuadraticFeatures_fit_transform(X_te, d)


        theta = lr.Ridge_fit(X_tr_n, y_tr, a)
        theta_ridge.append(theta)
        #print("thetavactor: ",theta)
        print(f'theta calculated!\nwith {len(theta)} coefficients\n')

        ######
        # predict on testdata
        ######

        y_pred_test = lr.Ridge_predict(X_te_n, theta)
        y_pred_train = lr.Ridge_predict(X_tr_n, theta)
        # print(y_pred_test)
        r2 = lr.r2_score(y_te, y_pred_test)
        r2_score_ridge.append(r2)
        # mse
        mse = lr.mean_squared_error(y_te, y_pred_test)
        mse2 = lr.mean_squared_error(y_tr, y_pred_train)
        mse_test.append(mse)
        mse_train.append(mse2)
        print(
            f'validation on testdata '
            +f'({np.shape(X_te_n)}):\nr2 = {r2}\nmse = {mse}\n')


        #######################################################################
        #plot mse r2
        ax.plot([X_te.T[column_to_plot],
                  X_te.T[column_to_plot]], [y_pred_test, y_te],
                 color='0.75', linestyle='dotted', linewidth=0.5)

        ax.scatter(X_te.T[column_to_plot], y_pred_test,
                    edgecolors='black', marker='x', label=f'degree = {d}\nalpha = {a}\nmse = {mse:.5f}')

        ax2.scatter(y_pred_test, y_te, marker='.', label=f'degree = {d}\nalpha = {a}\nr2 = {r2:.5f}')


    print('###############', '\n')
    print(
        f'plotting {features[column_to_plot]}'
        +f' ({column_to_plot}) traindata and predicted testdata now...')
        #legend.append('alpha={0:.2E} -> R2={1:.4E}'.format(float(alpha[i]),float(r2_score_ridge[i])))
    legend.append('training point')
    legend.append('original unknown point')

    ax.set_title(f'{features[column_to_plot]}: Trainingspunkte m_tr = {len(X_tr)} sowie Testpunkte m_t = {len(X_te)}')
    #ax.set_xlim(min(X.T[column_to_plot]) - 0.2, max(X.T[column_to_plot]) + 0.2)
    ax.set_xlabel('x')
    ax.set_ylabel('y')

    ax2.set_title('Residuum')
    ax2.set_xlabel('y predicted')
    ax2.set_ylim(0, ax.get_ylim()[1])
    ax2.set_ylabel('y')
    ax2.set_xlim(0,ax.get_ylim()[1])

    ax.scatter(X_tr.T[column_to_plot], y_tr, color='white',
                edgecolors='black', label="training point")
    ax.scatter(X_te.T[column_to_plot], y_te, color='black',
                marker='.', label="test point")

    ax2.plot(ax2.get_xlim(), ax2.get_ylim(), color='0.1', linestyle='-.', linewidth=0.5, label='r2 = 1')
    #fig.savefig(f'./pics/linearreg_{features[column_to_plot]}_{hyperparameter}_{np.shape(X_te)}.png', bbox_inches='tight')
    ax.legend()
    ax2.legend()
    ax2.grid(color='0.7', linestyle='-.', linewidth=0.5)
    plt.show()

    return hyperparameter, r2_score_ridge, mse_test, mse_train, cost, theta_ridge


def linear_ohneplot(degree=[1], alpha=[0], size=[100]):

    if not all(type(i) in (list, tuple, set) for i in [degree, alpha, size]):
        # if not type(degree) in (list, tuple, set, frozenset):
        print('WARNING: Hyperparameter muessen als Liste uebergeben werden.\n'
              + 'Verwende d=1 a=0 s=100.\n\n\n')
        degree = [1]
        alpha = [0]
        size = [100]

    r2_score_ridge = []
    mse_test = []
    mse_train = []
    cost = []
    theta_ridge = []
    fx = []
    legend = []
    #12345
    hyperparameter = list(product(degree, alpha, size))
    #hyperparameter =[[1,0.01,405],[2,0.01,405]]# [[1,600,200],[2,45339,405]]#,[3,8000000,200]]

    for hypr in hyperparameter:
        d, a, s = hypr  # Polynomengrad, alpha und datensetgroesse

        X_tr = X_train[:s]
        y_tr = y_train[:s]
        X_te = X_test#[:s]
        y_te = y_test#[:s]

        print(f'###############\ncalculating and plotting for:\n'
              + f'polynomialdegree = {d}\nalpha = {a}\n'
              + f'datasetsize = {np.shape(X_tr)}...\n')
        # print(_)
        X_tr_n = lr.QuadraticFeatures_fit_transform(X_tr, d)
        X_te_n = lr.QuadraticFeatures_fit_transform(X_te, d)

        # print(np.shape(X_tr),np.shape(X_tr_n),np.shape(y_tr),np.shape(a))

        theta = lr.Ridge_fit(X_tr_n, y_tr, a)
        theta_ridge.append(theta)
        #print("thetavactor: ",theta)
        print(f'theta calculated!\nwith {len(theta)} coefficients\n')

        ######
        # predict on testdata
        ######

        y_pred_test = lr.Ridge_predict(X_te_n, theta)
        y_pred_train = lr.Ridge_predict(X_tr_n, theta)
        # print(y_pred_test)
        r2 = lr.r2_score(y_te, y_pred_test)
        r2_score_ridge.append(r2)
        # mse
        mse = lr.mean_squared_error(y_te, y_pred_test)
        mse2 = lr.mean_squared_error(y_tr, y_pred_train)
        mse_test.append(mse)
        mse_train.append(mse2)
        print(
            f'validation on testdata '
            +f'({np.shape(X_te_n)}):\nr2 = {r2}\nmse = {mse}\n')




    print('###############', '\n')

    return hyperparameter, r2_score_ridge, mse_test, mse_train, cost, theta_ridge

# %%
####################
# load datasets
####################
dataset = load_boston()
print(dataset.DESCR, '\n', '\n')
X = dataset.data#[:-4]
y = dataset.target
features = dataset.feature_names
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
####################
# split dataset (60:20:20)
####################
X_train, X_test, y_train, y_test = lr.train_test_split(X, y, 0.6, 0)
X_test, X_val, y_test, y_val = lr.train_test_split(X_test, y_test, 0.5, 0)

# %%
####################
# explore trainingset
####################

# Häufigkeitsverteilung y (target)
fig = plt.figure(figsize=(9, 8))
plt.hist(y_train)
plt.xlabel('target value')
plt.ylabel('relative Häufigkeitsverteilung')
plt.title('Histogramm der mittleren Hauspreise der Trainingsdaten')
plt.show()

mean_train, std_train = [], []
coeffs = []

for ind, col in enumerate(X_train.T):
    # print(df[col].describe())
    mean, std = lr.StandardScaler_fit(col)
    mean_train.append(mean)
    std_train.append(std)
    print(f'{features[ind]} ({ind}):')
    fig1 = plt.figure(figsize=(16, 6))
    gs = gridspec.GridSpec(1, 2)
    ax = plt.subplot(gs[0])
    ax.set_xlabel(features[ind])
    ax.set_ylabel("relative Häufigkeitsverteilung")
    ax.set_title("")
    plt.hist(col)
    ##
    ##
    ax2 = plt.subplot(gs[1])
    ax2.set_xlabel(features[ind])
    ax2.set_ylabel("mittlerer Hauspreis")
    plt.scatter(col, y_train, alpha=0.4, )
    ##
    coeff = np.mean(np.corrcoef(col, y_train.T))
    coeffs.append(coeff)
    ax2.set_title("Korrelationskoeffizient: {0:.5f}".format(coeff))
    plt.show()

    #Feature beschreiben
    print(f'rows = {np.size(col)}\nall numeric = {not np.isnan(col).any()} ({col.dtype})\nmean = {mean}\nstd = {std}\ncorrcoef = {coeff}', '\n', '\n')
# Out:
# CRIM (0):
# rows = 405
# all numeric = True (float64)
# mean = 3.635520962962963
# std = 8.530077142454921
# corrcoef = 0.3006817424624604
#
#
# ZN (1):
# rows = 405
# all numeric = True (float64)
# mean = 11.301234567901234
# std = 23.311934599516583
# corrcoef = 0.6797439592064853
#
#
# INDUS (2):
# rows = 405
# all numeric = True (float64)
# mean = 11.172296296296297
# std = 6.754058855482355
# corrcoef = 0.23802732675263877
#
#
# CHAS (3):
# rows = 405
# all numeric = True (float64)
# mean = 0.07407407407407407
# std = 0.2618914004394621
# corrcoef = 0.5696149456313642
#
#
# NOX (4):
# rows = 405
# all numeric = True (float64)
# mean = 0.5561306172839506
# std = 0.11759750291656516
# corrcoef = 0.2673642961953273
#
#
# RM (5):
# rows = 405
# all numeric = True (float64)
# mean = 6.2805382716049385
# std = 0.6941262678330061
# corrcoef = 0.8451403632673958
#
#
# AGE (6):
# rows = 405
# all numeric = True (float64)
# mean = 67.90716049382716
# std = 28.268091737075626
# corrcoef = 0.2899996714142845
#
#
# DIS (7):
# rows = 405
# all numeric = True (float64)
# mean = 3.820037037037037
# std = 2.1685024363612784
# corrcoef = 0.6458490270170233
#
#
# RAD (8):
# rows = 405
# all numeric = True (float64)
# mean = 9.641975308641975
# std = 8.722199068582585
# corrcoef = 0.2886939151977635
#
#
# TAX (9):
# rows = 405
# all numeric = True (float64)
# mean = 410.2962962962963
# std = 165.46648196220661
# corrcoef = 0.25063963290164426
#
#
# PTRATIO (10):
# rows = 405
# all numeric = True (float64)
# mean = 18.50543209876543
# std = 2.1385399711841684
# corrcoef = 0.2479028338780731
#
#
# B (11):
# rows = 405
# all numeric = True (float64)
# mean = 354.3973827160494
# std = 94.27083622223107
# corrcoef = 0.6695723090974273
#
#
# LSTAT (12):
# rows = 405
# all numeric = True (float64)
# mean = 12.753679012345678
# std = 7.0675492842017915
# corrcoef = 0.13349987761953186

# %%
#############################################
# Kreuzvalidierung
#############################################
def crossval(X,y,d,k):
    train_folds_score = []
    validation_folds_score = []
    alpha = np.arange(0.03,0.04,0.0001)
    
    mse_test = []
    mse_per_alpha = []
    
    for a in list(alpha):
        for fold in range(0, k):
            
            m = X.shape[0]
            index = np.arange(m)
            np.random.shuffle(index)

            start = int((m/k)*fold)
            end = int((m/k)*(fold+1))

            val = X[index[start:end]]
            val_y = y[index[start:end]]
            
            train = np.concatenate((X[index[:start]], X[index[end:]]))
            train_y = np.concatenate((y[index[:start]], y[index[end:]]))

            #print(np.shape(training),np.shape(validation))
            val = lr.QuadraticFeatures_fit_transform(val, d)
            train = lr.QuadraticFeatures_fit_transform(train, d)

            theta = lr.Ridge_fit(train, train_y, a)

            val_pred = lr.Ridge_predict(val, theta)

            mse = lr.mean_squared_error(val_y, val_pred)
            mse_test.append(mse)
            
        
        mse_per_alpha.append(np.mean(mse_test))
        mse_test = []
        
    return alpha, mse_per_alpha

# %%
alpha, mse = crossval(X_train,y_train, 2, 5)

# %%
fig = plt.figure(figsize=(14, 8))
plt.plot(alpha,np.sqrt(mse))
plt.xlabel('alpha')
plt.ylabel('root mse')
plt.show()

# %%
#############################################
# Hyperparameter
#############################################

column_to_plot = 5

# degree = [1]
# alpha = [600]
# size = list(range(1,405,1))
degree = [1,2]
alpha = [0.034,0.035]
size = [4000]

# %%
## Datenset erneut
X_train, X_test, y_train, y_test = lr.train_test_split(X, y, 0.6, 0)
X_test, X_val, y_test, y_val = lr.train_test_split(X_test, y_test, 0.5, 0)
X_train = np.vstack((X_train, X_val))
y_train = np.hstack((y_train, y_val))

print(X_train.shape,y_train.shape)
# Out:
# (405, 13) (405,)

# %%
hyperparameter, r2_score_ridge, mse_test, mse_train, cost, theta_ridge = linear(degree, alpha, size)
# Out:
# ###############
# calculating and plotting for:
# polynomialdegree = 1
# alpha = 0.034
# datasetsize = (405, 13)...
#
# theta calculated!
# with 14 coefficients
#
# validation on testdata ((101, 13)):
# r2 = 0.7261814138787746
# mse = 15.763383026388075
#
# ###############
# calculating and plotting for:
# polynomialdegree = 1
# alpha = 0.035
# datasetsize = (405, 13)...
#
# theta calculated!
# with 14 coefficients
#
# validation on testdata ((101, 13)):
# r2 = 0.7261699670957937
# mse = 15.764042002928358
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.034
# datasetsize = (405, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = 0.9279316349600579
# mse = 4.148882872790864
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (405, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = 0.9279300628202691
# mse = 4.148973378851875
#
# ###############
#
# plotting RM (5) traindata and predicted testdata now...

# %%
degree = [2]
alpha = [0.035]
size = list(range(1,len(X_train),1))
hyperparameter, r2_score_ridge, mse_test, mse_train, cost, theta_ridge = linear_ohneplot(degree, alpha, size)
# Out:
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (1, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -0.007002936160540596
# mse = 57.97186091804724
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (2, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -3.7012584792392014
# mse = 270.64539030777536
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (3, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -2.740564739098013
# mse = 215.3394901078729
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (4, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -40.724105660622655
# mse = 2402.00297678368
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (5, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -27.273932206114022
# mse = 1627.693829482368
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (6, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -27.467581865649322
# mse = 1638.8419907501102
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (7, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -26.92487187184376
# mse = 1607.5988760083726
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (8, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -8.989917646876295
# mse = 575.1066810346722
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (9, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -5.643360138228999
# mse = 382.4496792733402
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (10, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -1.5140790223867655
# mse = 144.73228844642648
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (11, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -0.2517647653614712
# mse = 72.06248390528854
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (12, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -0.25055181089263723
# mse = 71.99265568012439
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (13, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -1.0147084248406015
# mse = 115.98416687899035
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (14, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -3.8063182742118
# mse = 276.69354727288976
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (15, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -4.072139696782191
# mse = 291.99654390271434
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (16, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -3.8974477170525086
# mse = 281.93975182323925
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (17, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -7.022252132078075
# mse = 461.8307138443095
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (18, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -7.0811099411308795
# mse = 465.21908203850734
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (19, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -10.86685039086635
# mse = 683.1592795722532
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (20, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -21.837473286626345
# mse = 1314.7238975685125
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (21, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -11.923167257433514
# mse = 743.9700798937496
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (22, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -14.956984600005988
# mse = 918.6230334441574
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (23, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -13.776678295932143
# mse = 850.6743210388593
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (24, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -12.401225671010918
# mse = 771.4912865034125
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (25, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -12.806755499869482
# mse = 794.8371159866349
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (26, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -11.347125271408364
# mse = 710.8080853278451
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (27, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -0.5980106085922363
# mse = 91.99541075827028
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (28, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -1.1712510173614001
# mse = 124.99612213303092
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (29, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -1.546369257247561
# mse = 146.59119564236605
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (30, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -1.9320108521260888
# mse = 168.79208513306742
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (31, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -1.0380906862925796
# mse = 117.33025352895756
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (32, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -0.7695511732307649
# mse = 101.87077993340313
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (33, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -0.6539472840376306
# mse = 95.21561305629156
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (34, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -0.6455740816264801
# mse = 94.7335785872873
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (35, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -1.5401967845882947
# mse = 146.23585434824062
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize = (36, 13)...
#
# theta calculated!
# with 105 coefficients
#
# validation on testdata ((101, 104)):
# r2 = -1.5294996665405214
# mse = 145.62003505177074
#
# ###############
# calculating and plotting for:
# polynomialdegree = 2
# alpha = 0.035
# datasetsize =